# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
c = sns.load_dataset('titanic')

# %%
print(c)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
c.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
c.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print(c.dtypes)
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
c.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print(c.pclass)
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
c['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
c['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
np.mean
c['survived']
c['pclass']==1
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: pclass, Length: 891, dtype: bool

# %%
c[["pclass","survived"]].groupby(['pclass']).mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
c.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print("no of column are",len(c))
# Out:
# no of column are 891

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
print(len(c[c['survived']==1]))
# Out:
# 342

# %%
print(len(c[c['survived']==0]))
# Out:
# 549

# %%
c['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
c[["sex","survived"]].groupby(['sex']).mean()*100
# Out:
#          survived
# sex
# female  74.203822
# male    18.890815

# %%
c['age'].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
c[c["sex"]== 'male'].groupby("pclass")["survived"].sum()
# Out:
# pclass
# 1    45
# 2    17
# 3    47
# Name: survived, dtype: int64

# %%
c[c["sex"]== 'female'].groupby("pclass")["survived"].sum()
# Out:
# pclass
# 1    91
# 2    70
# 3    72
# Name: survived, dtype: int64

# %%
sns.catplot(x="sex",hue = "survived", kind= "count",data= c)

# %%
sns.catplot(x="sex",hue = "pclass", kind= "count",data= c)

# %%
sns.catplot(x='sex', y='survived', hue='pclass', kind='violin', data=c)

# %%
sns.catplot(x='sex', y='survived', hue='pclass', kind='boxen', data= c)

# %%
sns.catplot(x="pclass",hue = "survived", kind= "count",data= c)

# %%
sns.catplot(x="pclass", y = "survived",hue = "sex", kind= "bar",data= c)

# %%
sns.catplot(x="sex", y = "survived",hue = "pclass", kind= "bar",data= c)

# %%
c[
    (c["sex"]== "female") & (c["survived"]==1)

].groupby("pclass")["survived"].count()
# Out:
# pclass
# 1    91
# 2    70
# 3    72
# Name: survived, dtype: int64

# %%
c[
    (c["sex"]== "male") & (c["survived"]==1)

].groupby("pclass")["survived"].count()
# Out:
# pclass
# 1    45
# 2    17
# 3    47
# Name: survived, dtype: int64

# %%
c[
    (c["sex"]== "male") & (c["survived"]==0)

].groupby("pclass")["survived"].count()
# Out:
# pclass
# 1     77
# 2     91
# 3    300
# Name: survived, dtype: int64

# %%
sns.heatmap(c.isnull())
# Out:
# <Axes: >

# %%
c.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
sns.catplot(x="embarked", hue="survived", kind="count", col="pclass", data=c)

# %%
c[c["sex"] == "male"].groupby("pclass")["survived"].sum()
# Out:
# pclass
# 1    45
# 2    17
# 3    47
# Name: survived, dtype: int64

# %%
c[c["sex"] == "female"].groupby("pclass")["survived"].sum()
# Out:
# pclass
# 1    91
# 2    70
# 3    72
# Name: survived, dtype: int64

# %%
c[c["pclass"] == "male"].groupby("pclass")["survived"].sum()
# Out:
# Series([], Name: survived, dtype: int64)

# %%
sns.catplot(
    x="pclass",
    y="survived",
    hue="sex",
    kind="bar",
    data=c
)

# Display the plot
plt.show()

# %%
c[
    (c['sex'] == 'female') & (c['survived'] == 1)
].groupby("class")["survived"].count()
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_29388\3578694361.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ].groupby("class")["survived"].count()
# class
# First     91
# Second    70
# Third     72
# Name: survived, dtype: int64

# %%
c[
    (c['sex'] == 'male') & (c['survived'] == 1)
].groupby("class")["survived"].count()
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_29388\3034805547.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ].groupby("class")["survived"].count()
# class
# First     45
# Second    17
# Third     47
# Name: survived, dtype: int64

# %%
c[
    (c['sex'] == 'female') & (c['survived'] == 0)
].groupby("class")["survived"].count()
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_29388\1996816159.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ].groupby("class")["survived"].count()
# class
# First      3
# Second     6
# Third     72
# Name: survived, dtype: int64

# %%
c[
    (c['sex'] == 'male') & (c['survived'] == 0)
].groupby("class")["survived"].count()
# Out:
# C:\Users\shind\AppData\Local\Temp\ipykernel_29388\4163340784.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ].groupby("class")["survived"].count()
# class
# First      77
# Second     91
# Third     300
# Name: survived, dtype: int64

# %%
sns.heatmap(c.isnull(), cmap="magma")
# Out:
# <Axes: >
